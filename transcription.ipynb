# %%
import whisper
import csv
import os;
import warnings
from tqdm import tqdm
import jiwer 

transforms = jiwer.Compose(
    [
        jiwer.ExpandCommonEnglishContractions(),
        jiwer.RemoveEmptyStrings(),
        jiwer.ToLowerCase(),
        jiwer.RemoveMultipleSpaces(),
        jiwer.Strip(),
        jiwer.RemovePunctuation(),
        jiwer.ReduceToListOfListOfWords(),
    ]
)

# Suppress specific warnings
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=FutureWarning)

#can add other supported formates and can also write code to convert formates  which is not needed in our dataset
supported_formats = (".mp3") 

def transcribe_with_whisper(audio_dir):
    transcriptions = []
    files = [f for f in os.listdir(audio_dir) if f.endswith(supported_formats)]

    for filename in tqdm(files, desc="Transcribing audio files"):
        file_path = os.path.join(audio_dir, filename)
        
        # Load the Whisper model
        model = whisper.load_model("base")  #can change "base" to "large" for higher accuracy; 'base' is faster; 'large' gives better accuracy
        
        # Perform transcription
        result = model.transcribe(file_path)

        # Get ground truth from corresponding .txt file
        txt_filename = os.path.splitext(filename)[0] + ".txt"
        txt_path = os.path.join(audio_dir, txt_filename)
        if os.path.exists(txt_path):
            with open(txt_path, "r", encoding="utf-8") as gt_file:
                ground_truth = gt_file.read()
                predicted_text = result["text"] 
                #Word Error Rate calculation
                error = jiwer.wer(ground_truth, 
                            predicted_text,
                            truth_transform=transforms,
                            hypothesis_transform=transforms,)
                #calculate accuracy
                accuracy = (1 - error) * 100
        else:
            ground_truth = ""
            accuracy = 0.0

        transcriptions.append({
            "filename": filename,
            "transcription": predicted_text,
            "ground_truth": ground_truth,
            "accuracy": round(accuracy, 2)
        })
    
    return transcriptions

def save_transcriptions_to_csv(transcriptions, output_file="baseTranscriptions.csv"):
    # Open the CSV file and write the transcriptions
     with open(output_file, mode="w", newline="", encoding="utf-8") as file:
        writer = csv.writer(file)
        writer.writerow(["Filename", "Transcription", "Ground Truth", "Accuracy (%)"])
        for entry in transcriptions:
            writer.writerow([entry["filename"], entry["transcription"], entry["ground_truth"], entry["accuracy"]])

# Run transcription on the audio datasets
audio_dir = "dataset/a/"
transcriptions = transcribe_with_whisper(audio_dir)
print("Transcriptions : ", transcriptions)

# Calculate overall accuracy,
# Treat negative accuracies as 0
adjusted_accuracies = [entry["accuracy"] if entry["accuracy"] >= 0 else 0 for entry in transcriptions]

# Calculate overall accuracy
if adjusted_accuracies:
    overall_accuracy = sum(adjusted_accuracies) / len(adjusted_accuracies)
    print(f"\nOverall Accuracy (adjusted): {overall_accuracy:.2f}%")

# Save the transcriptions to CSV
save_transcriptions_to_csv(transcriptions)
print("Transcriptions saved to baseTranscriptions.csv")
# Out:
# Transcribing audio files: 100%|████████████████████████████████████████████████████████| 39/39 [02:56<00:00,  4.52s/it]
# Transcriptions :  [{'filename': '103.536_107.319.mp3', 'transcription': " and the doctors taking the wavid's temperature.", 'ground_truth': 'and the doctor is taking the rabbit is temperature', 'accuracy': 66.67}, {'filename': '109.101_110.662.mp3', 'transcription': " And then he's all better.", 'ground_truth': 'and then he is all better', 'accuracy': 100.0}, {'filename': '116.372_119.993.mp3', 'transcription': ' I really enjoyed both.', 'ground_truth': 'the rabbit sees the animal with a balloon and he waves', 'accuracy': 0.0}, {'filename': '122.054_125.555.mp3', 'transcription': ' The rabbit is getting the balloon.', 'ground_truth': 'the rabbit is grabbing the balloon', 'accuracy': 83.33}, {'filename': '127.676_130.156.mp3', 'transcription': ' And now the weather is playing with the balloon.', 'ground_truth': 'and now the rabbit is playing with the balloon', 'accuracy': 88.89}, {'filename': '131.617_134.318.mp3', 'transcription': ' by accident he let go of it.', 'ground_truth': 'and by accident he let go of it', 'accuracy': 87.5}, {'filename': '135.738_137.579.mp3', 'transcription': " I know it's wrapped in this guy.", 'ground_truth': 'and now it is way up in the sky', 'accuracy': 33.33}, {'filename': '139.219_141.56.mp3', 'transcription': ' and then they see a man with balloon.', 'ground_truth': 'and then they see a man with balloons', 'accuracy': 87.5}, {'filename': '143.934_147.117.mp3', 'transcription': ' and the bunny asks if he can get one.', 'ground_truth': 'and the bunny asks if he can get one', 'accuracy': 100.0}, {'filename': '156.604_159.866.mp3', 'transcription': " And then he frowns because he doesn't have any money.", 'ground_truth': 'and then he frowns because he does not have any money', 'accuracy': 100.0}, {'filename': '161.588_165.851.mp3', 'transcription': ' And then he wants to his dad or his mom or whatever.', 'ground_truth': 'and then he runs to his dad or his mom or whatever', 'accuracy': 91.67}, {'filename': '167.512_171.035.mp3', 'transcription': ' And he asks, what to buy him a balloon.', 'ground_truth': 'and he asks her to buy him a balloon', 'accuracy': 88.89}, {'filename': '181.605_186.566.mp3', 'transcription': ' them too', 'ground_truth': 'okay the giraffe and the elephant are bouncing a ball', 'accuracy': 0.0}, {'filename': '188.146_189.626.mp3', 'transcription': ' it goes into the prudence.', 'ground_truth': 'it goes into the pool', 'accuracy': 80.0}, {'filename': '189.646_197.128.mp3', 'transcription': ' Yeah. Yeah. Pinch your story.', 'ground_truth': 'it is your story', 'accuracy': 25.0}, {'filename': '204.56_207.241.mp3', 'transcription': ' and then he brings it out to the elephant.', 'ground_truth': 'and then he brings it out to the elephant', 'accuracy': 100.0}, {'filename': '224.644_227.505.mp3', 'transcription': ' and a film to go off the diving board.', 'ground_truth': 'the elephant wants to go off the diving board', 'accuracy': 66.67}, {'filename': '229.045_230.026.mp3', 'transcription': ' She slept.', 'ground_truth': 'she slips', 'accuracy': 50.0}, {'filename': '233.433_236.374.mp3', 'transcription': ' She found she could only...', 'ground_truth': 'she fell and she hurt her knee', 'accuracy': 28.57}, {'filename': '238.335_240.696.mp3', 'transcription': " And now the life's cold cup is rushing over.", 'ground_truth': 'and now the lifeguard comes rushing over', 'accuracy': 28.57}, {'filename': '247.059_250.921.mp3', 'transcription': ' And then the elephant walks over to the bed.', 'ground_truth': 'and then the elephant walks over to the bench', 'accuracy': 88.89}, {'filename': '258.364_261.205.mp3', 'transcription': " It's a cave, the giraffe.", 'ground_truth': 'okay the giraffe', 'accuracy': -33.33}, {'filename': '261.967_264.289.mp3', 'transcription': ' as the airplane on the plane with it.', 'ground_truth': 'has the airplane and they are playing with it', 'accuracy': 44.44}, {'filename': '284.245_286.307.mp3', 'transcription': ' and then the giraffe is mad.', 'ground_truth': 'then t ...
#
# Overall Accuracy (adjusted): 66.52%
# Transcriptions saved to baseTranscriptions.csv

# %%
import whisper
import csv
import os;
import warnings
from tqdm import tqdm
import jiwer 

transforms = jiwer.Compose(
    [
        jiwer.ExpandCommonEnglishContractions(),
        jiwer.RemoveEmptyStrings(),
        jiwer.ToLowerCase(),
        jiwer.RemoveMultipleSpaces(),
        jiwer.Strip(),
        jiwer.RemovePunctuation(),
        jiwer.ReduceToListOfListOfWords(),
    ]
)

# Suppress specific warnings
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=FutureWarning)

#can add other supported formates and can also write code to convert formates by using  which is not needed in our dataset
supported_formats = (".mp3") 

def transcribe_with_whisper(audio_dir):
    transcriptions = []
    files = [f for f in os.listdir(audio_dir) if f.endswith(supported_formats)]

    for filename in tqdm(files, desc="Transcribing audio files"):
        file_path = os.path.join(audio_dir, filename)
        
        # Load the Whisper model
        model = whisper.load_model("base")  #can change "base" to "large" for higher accuracy; 'base' is faster; 'large' gives better accuracy
        
        # Perform transcription
        result = model.transcribe(file_path)

        # Get ground truth from corresponding .txt file
        txt_filename = os.path.splitext(filename)[0] + ".txt"
        txt_path = os.path.join(audio_dir, txt_filename)
        if os.path.exists(txt_path):
            with open(txt_path, "r", encoding="utf-8") as gt_file:
                ground_truth = gt_file.read()
                predicted_text = result["text"] 
                #Word Error Rate calculation
                error = jiwer.wer(ground_truth, 
                            predicted_text,
                            truth_transform=transforms,
                            hypothesis_transform=transforms,)
                #calculate accuracy
                accuracy = (1 - error) * 100
        else:
            ground_truth = ""
            accuracy = 0.0

        transcriptions.append({
            "filename": filename,
            "transcription": predicted_text,
            "ground_truth": ground_truth,
            "accuracy": round(accuracy, 2)
        })
    
    return transcriptions

def save_transcriptions_to_csv(transcriptions, output_file="baseTranscriptions1.csv"):
    # Open the CSV file and write the transcriptions
     with open(output_file, mode="w", newline="", encoding="utf-8") as file:
        writer = csv.writer(file)
        writer.writerow(["Filename", "Transcription", "Ground Truth", "Accuracy (%)"])
        for entry in transcriptions:
            writer.writerow([entry["filename"], entry["transcription"], entry["ground_truth"], entry["accuracy"]])

# Run transcription on the audio datasets
audio_dir = "dataset/b/"
transcriptions = transcribe_with_whisper(audio_dir)
print("Transcriptions : ", transcriptions)

# Calculate overall accuracy,
# Treat negative accuracies as 0
adjusted_accuracies = [entry["accuracy"] if entry["accuracy"] >= 0 else 0 for entry in transcriptions]

# Calculate overall accuracy
if adjusted_accuracies:
    overall_accuracy = sum(adjusted_accuracies) / len(adjusted_accuracies)
    print(f"\nOverall Accuracy (adjusted): {overall_accuracy:.2f}%")

# Save the transcriptions to CSV
save_transcriptions_to_csv(transcriptions)
print("Transcriptions saved to baseTranscriptions1.csv")
# Out:
# Transcribing audio files: 100%|████████████████████████████████████████████████████████| 51/51 [09:08<00:00, 10.76s/it]
# Transcriptions :  [{'filename': '104.73_105.551.mp3', 'transcription': ' all done.', 'ground_truth': 'all done', 'accuracy': 100.0}, {'filename': '121.222_121.803.mp3', 'transcription': ' learning. you', 'ground_truth': 'no running', 'accuracy': 0.0}, {'filename': '155.967_183.103.mp3', 'transcription': " The drafts can get her. Not to fall down. The elephant is hurt. In the elephant he's crying in the draft is help in the...", 'ground_truth': 'giraffe is going to get her not to fall down the elephant is hurt and the elephant he is crying and the giraffe is helping', 'accuracy': 60.0}, {'filename': '201.003_203.184.mp3', 'transcription': ' It hurts.', 'ground_truth': 'it hurts', 'accuracy': 100.0}, {'filename': '205.665_206.465.mp3', 'transcription': ' done', 'ground_truth': 'hold still', 'accuracy': 0.0}, {'filename': '206.585_208.246.mp3', 'transcription': " I won't hurt him.", 'ground_truth': 'it will not hurt', 'accuracy': 50.0}, {'filename': '214.989_215.429.mp3', 'transcription': ' Thank you.', 'ground_truth': 'mikey', 'accuracy': -100.0}, {'filename': '216.491_220.895.mp3', 'transcription': ' And he came and looked at that.', 'ground_truth': 'and he came and he looked at it', 'accuracy': 75.0}, {'filename': '221.575_230.663.mp3', 'transcription': ' necesitmayıste Francis', 'ground_truth': 'it was bleeding', 'accuracy': 0.0}, {'filename': '246.445_257.071.mp3', 'transcription': ' Mikey Draft, he was helping the helping get the awesome home.', 'ground_truth': 'the mikey giraffe he was helping get the elephant home', 'accuracy': 50.0}, {'filename': '276.897_277.257.mp3', 'transcription': ' No.', 'ground_truth': 'no', 'accuracy': 100.0}, {'filename': '283.841_284.161.mp3', 'transcription': '', 'ground_truth': 'yeah', 'accuracy': 0.0}, {'filename': '297.828_299.549.mp3', 'transcription': ' and the elephant said yes.', 'ground_truth': 'and the elephant said yes', 'accuracy': 100.0}, {'filename': '319.451_323.594.mp3', 'transcription': ' Like he said, no, no, no.', 'ground_truth': 'and mikey said no no no', 'accuracy': 66.67}, {'filename': '328.258_333.062.mp3', 'transcription': ' CR Hell!', 'ground_truth': 'whoops', 'accuracy': -100.0}, {'filename': '334.643_337.025.mp3', 'transcription': ' Now you put it on the water.', 'ground_truth': 'now you put it on the water', 'accuracy': 100.0}, {'filename': '338.51_339.33.mp3', 'transcription': 'あとに上がれ', 'ground_truth': 'you get it', 'accuracy': 0.0}, {'filename': '342.692_344.332.mp3', 'transcription': ' He got mad.', 'ground_truth': 'and he got mad', 'accuracy': 75.0}, {'filename': '346.453_347.834.mp3', 'transcription': ' is not happy.', 'ground_truth': 'he is not happy', 'accuracy': 75.0}, {'filename': '379.342_381.122.mp3', 'transcription': " And that's not very nice.", 'ground_truth': 'and that is not very nice', 'accuracy': 100.0}, {'filename': '38.514_41.654.mp3', 'transcription': ' Um, um, okay.', 'ground_truth': 'okay', 'accuracy': -100.0}, {'filename': '390.887_394.348.mp3', 'transcription': ' and what happened, I think they were...', 'ground_truth': 'and what happened i did not do it', 'accuracy': 50.0}, {'filename': '397.099_399.26.mp3', 'transcription': ' making up a best friend or more.', 'ground_truth': 'mikey is not my best friend no more', 'accuracy': 37.5}, {'filename': '399.28_400.96.mp3', 'transcription': ' Okay.', 'ground_truth': 'okay', 'accuracy': 100.0}, {'filename': '404.882_406.923.mp3', 'transcription': " I can't reach it.", 'ground_truth': 'i can not reach it', 'accuracy': 100.0}, {'filename': '415.906_418.107.mp3', 'transcription': ' and making his crying.', 'ground_truth': 'and mikey is crying', 'accuracy': 50.0}, {'filename': '458.902_460.343.mp3', 'transcription': ' already', 'ground_truth': 'it is already', 'accuracy': 33.33}, {'filename': '463.008_466.29.mp3', 'transcription': " And make you said don'tgramm and torch.", 'ground_truth': 'and mikey said do not grab my toy', 'accuracy': 25.0}, {'filename': '467.031_467.972.mp3', 'transcription': " Then ...
#
# Overall Accuracy (adjusted): 49.67%
# Transcriptions saved to baseTranscriptions1.csv
